# %% [markdown]
# # Regressions using Decision Trees and Random Forests

# %% [markdown]
# ### Part 1. Decision Tree Regression Theory/Intuition

# %% [markdown]
# Imagine we have the following Data. We are given 2 inputs (X1 and X2) and our goal is to predict the output, the Y value. An example of this would be to predict someone's job based on their salary and years with the company, a problem we will encounter later on. First, lets look at the graph of the two inputs X1 and X2.
# ![rsz_screen_shot_2018-11-27_at_125351_pm.jpg](attachment:rsz_screen_shot_2018-11-27_at_125351_pm.jpg)

# %% [markdown]
# When it is scattered like this, linear and logistic regression would not be useful tools. Given that this is still a regression problem, we want to use another regression model. In this case, we'll use Decision Tree regression as our model.

# %% [markdown]
# #### Here is what the decision tree regression will do to our data

# %% [markdown]
# ![rsz_screen_shot_2018-11-27_at_10554_pm.jpg](attachment:rsz_screen_shot_2018-11-27_at_10554_pm.jpg)

# %% [markdown]
# The model makes split 1, then 2, etc. You may be wondering what the logic behind where the model makes these splits. Decision Tree Regression utilizes something called Informational Entropy. Informational Entropy asks whther or not a split will increase the amount of meaninful information about our points. It stops when there can be no additional information added in the process of splitting the data. This is a complex topic that you do not need to fully understand to use Decision Tree regression. If you are curious, see the wikipedia page and the khan academy video which explains it pretty well.
#
# Wikipedia Link: https://en.wikipedia.org/wiki/Entropy_(information_theory) <br>
# Khan Academy Video: https://www.youtube.com/watch?v=2s3aJfRr9gE

# %% [markdown]
# #### Visualing our Decision Tree

# %% [markdown]
# We can visualize the graph as a tree of yes/no decisions, hence the name Decision Tree. Let's take a look.

# %% [markdown]
# ![rsz_screen_shot_2018-11-27_at_11918_pm.jpg](attachment:rsz_screen_shot_2018-11-27_at_11918_pm.jpg)

# %% [markdown]
# #### Some Basic Tree Terminology
# Each rectangle on the tree is a node. <br>
# The node directly above any given node is a parent. <br>
# The node directly under any given node is a child. <br>
# The topmost node is called the root. <br>
# Nodes without children are called leaves.

# %% [markdown]
# Let's say we have X1 = 30 and X3 = 50, which leaf will that coordinate end up in? <br> (Leaf 1 is the leftmost leaf and Leaf 5 is the rightmost leaf)

# %% [markdown]
# #### Making our prediction

# %% [markdown]
# How does the Decision Tree model make a prediction? It is quite simple actually. <br>It averages all the Y values of the data points in the leaf where the input coordinates lie.

# %% [markdown]
# ![rsz_screen_shot_2018-11-27_at_13444_pm.jpg](attachment:rsz_screen_shot_2018-11-27_at_13444_pm.jpg)

# %% [markdown]
# ![rsz_screen_shot_2018-11-27_at_13812_pm.jpg](attachment:rsz_screen_shot_2018-11-27_at_13812_pm.jpg)

# %% [markdown]
# So what would our model predict with X1 = 180 and X2 = 95 for inputs?

# %% [markdown]
# ### Part 2. Creating a Decision Tree Regression model using Python

# %% [markdown]
# Download the dataset: https://drive.google.com/open?id=1zZjbt4BIs_P9Ww7J-_E9wwOlGPXks7Dz

# %%
#Import the Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Loading in the dataset
dataset = pd.read_csv('Position_Salaries.csv')
x1 = dataset.iloc[:, 1].values
x2 = dataset.iloc[:, 2].values

# %%
#Creating our regresson
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state = 0)
regressor.fit(x1,x2)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=0, splitter='best')

# %%
#6.5 an arbitrary value for our prediction
y_pred = regressor.predict(6.5) 
print("Predicted model: ", y_pred)
# Out:
# Predicted model:  [150000.]

# %%
#Visualing the Decision Tree Regression results via MatPlotLib
X_grid = np.arange(min(x1), max(x1), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(x1, x2, color = 'red')
plt.plot(X_grid, regressor.predict(X_grid), color = 'blue')
plt.title('Job Title as a function of Position level and Salary')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ### Part 3. Random Forest Regression Theory/Intuition

# %% [markdown]
# Random Forest regression uses many decision trees to create a more accurate regression model. We build Random Forests by a process called Ensemble Learning. Ensemble Learning involves creating many trained agents and using them to make a prediction. Here are the steps for creating a Random Forest to perform regression on.

# %% [markdown]
# 1. Pick a Random K data points from the dataset <br>
# 2. Build a Decision Tree Based on these K data points <br>
# 3. Choose the number of trees you want to build and repeat steps 1&2 <br>
# 4. For a new data point, average the predictions of all the decision trees you've created <br>
# 5. That is the Random Forest's Prediction!

# %% [markdown]
# Consider the classic guessing game where players have to guess the number of things in a jar.
# It is of course, very difficult to guess the number on your own but a little bit of data collection can vastly improve your chances.
# If you stand next to the jar and ask each person who guesses what they guessed and then wrote it down, you could average the data and get a number which is more likely to be the closest to the actual number. Similarly, a random forest averages the values of all the decision trees in the forest, thus improving its prediction's accuracy.

# %% [markdown]
# ![IMG_4487b.jpg](attachment:IMG_4487b.jpg)

# %% [markdown]
# ### Part 4. Creating a Random Forest in Python

# %% [markdown]
# We will once again be using our Position Salaries dataset to demonstrate how to create a Random Forest suitable for regression.

# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Importing the dataset
dataset = pd.read_csv('Position_Salaries.csv')
x1 = dataset.iloc[:, 1:2].values
x2 = dataset.iloc[:, 2].values

# %%
# Creating our Regressor
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 100, random_state = 0)
regressor.fit(X, y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#            oob_score=False, random_state=0, verbose=0, warm_start=False)

# %%
# Predicting a new result
y_pred = regressor.predict(6.5)

# %%
# Visualising the Random Forest Regression results (higher resolution)
X_grid = np.arange(min(X), max(X), 0.01)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'blue')
plt.plot(X_grid, regressor.predict(X_grid), color = 'red')
plt.title('Job Title as a function of Position level and Salary')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# Now that you have a good understanding of Decision Trees and Random Forests, come up with your own dataset which you think can be used for Decision Tree or Random Forest Regression. Then, search the web for harder datasets with more variables. I recommend looking at the UCI Machine Learning Repository: https://archive.ics.uci.edu/ml/datasets.html. <br>
